# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np
import seaborn as sns
import matplotlib.patches
import scipy.stats as stats
from datetime import datetime
plt.style.use('ggplot')
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("/Users/jethin/Google_Drive/Capstone/MSDS_Capstone-master/data/BTC_Score/Twitter_Sentiment_Scores_V2.csv")

# %%
df=df.dropna()

# %%
df.head()
# Out:
#   Created_Dt  Text_Score  Vader_Score     Price
# 0     3/4/18    0.447378     0.080227  11479.73
# 1     3/5/18    0.455178     0.072367  11432.98
# 2     3/6/18    0.467691     0.071270  10709.53
# 3     3/7/18    0.409716     0.024839   9906.80
# 4     3/8/18    0.390016     0.059968   9299.28

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = df.plot(x="Created_Dt", y="Vader_Score", legend=False,color='b')
ax2 = ax.twinx()
df.plot(x="Created_Dt", y="Price", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = df.plot(x="Created_Dt", y="Text_Score", legend=False,color='b')
ax2 = ax.twinx()
df.plot(x="Created_Dt", y="Price", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()
